# %%
import pandas as pd

# %%
data_df = pd.read_csv('../data/survey_results_public.csv')
schema_df = pd.read_csv('../data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 115)
pd.set_option('display.max_rows', 85)

# %%
data_df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
schema_df.head()
# Out:
#       qid       qname                                           question  \
# 0    QID2  MainBranch  Which of the following options best describes ...
# 1  QID127         Age                                 What is your age?*
# 2  QID296  Employment  Which of the following best describes your cur...
# 3  QID308  RemoteWork  Which best describes your current work situation?
# 4  QID341       Check  Just checking to make sure you are paying atte...
#
#   force_resp type selector
# 0       True   MC     SAVR
# 1       True   MC     SAVR
# 2       True   MC     MAVR
# 3      False   MC     SAVR
# 4       True   MC     SAVR

# %%
person = {
    "first": "Gullu",
    "last": "Ji",
    "email": "gullu@test.com"
}

# %%
people = {
    "first": ["gullu", "shiv", "laxman"],
    "last": ["Ji", "Kumar", "Singh"],
    "email": ["gullu@test.com", "shiv@test.com", "laxman@test.com"]
}

# %%
people['email']
# Out:
# ['gullu@test.com', 'shiv@test.com', 'laxman@test.com']

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#     first   last            email
# 0   gullu     Ji   gullu@test.com
# 1    shiv  Kumar    shiv@test.com
# 2  laxman  Singh  laxman@test.com

# %%
df['email']
# Out:
# 0     gullu@test.com
# 1      shiv@test.com
# 2    laxman@test.com
# Name: email, dtype: object

# %%
# we can use either of the approaches for accessing the databse, but in case say there is a column called could, below approach may not work, as it will return the count of items in dataframe
df.email
# Out:
# 0     gullu@test.com
# 1      shiv@test.com
# 2    laxman@test.com
# Name: email, dtype: object

# %%
type(df.email)
# Out:
# pandas.core.series.Series

# %%
df[['email', 'last']] # guess the data type of this?
# Out:
#              email   last
# 0   gullu@test.com     Ji
# 1    shiv@test.com  Kumar
# 2  laxman@test.com  Singh

# %%
df.iloc[0]
# Out:
# first             gullu
# last                 Ji
# email    gullu@test.com
# Name: 0, dtype: object

# %%
df.iloc[[0, 2]] # return a dataframe with item first and thrid item.
# Out:
#     first   last            email
# 0   gullu     Ji   gullu@test.com
# 2  laxman  Singh  laxman@test.com

# %%
df.iloc[[0, 1], [1, 2]]
# Out:
#     last           email
# 0     Ji  gullu@test.com
# 1  Kumar   shiv@test.com

# %%
df
# Out:
#     first   last            email
# 0   gullu     Ji   gullu@test.com
# 1    shiv  Kumar    shiv@test.com
# 2  laxman  Singh  laxman@test.com

# %%
df.loc[0] # here 0 is actually a label and not index
# Out:
# first             gullu
# last                 Ji
# email    gullu@test.com
# Name: 0, dtype: object

# %%
df.loc[[0, 2]] # just like iloc we can access specific rows by passing the row labels
# Out:
#     first   last            email
# 0   gullu     Ji   gullu@test.com
# 2  laxman  Singh  laxman@test.com

# %%
df.loc[[0, 2], ['first', 'email']]
# Out:
#     first            email
# 0   gullu   gullu@test.com
# 2  laxman  laxman@test.com

# %%
data_df.shape
# Out:
# (65437, 114)

# %%
data_df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
data_df['RemoteWork'].value_counts()
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    23015
# Remote                                  20831
# In-person                               10960
# Name: count, dtype: int64

# %%
data_df['RemoteWork']
# Out:
# 0                                      Remote
# 1                                      Remote
# 2                                      Remote
# 3                                         NaN
# 4                                         NaN
#                          ...
# 65432                                  Remote
# 65433                                  Remote
# 65434                               In-person
# 65435    Hybrid (some remote, some in-person)
# 65436                                     NaN
# Name: RemoteWork, Length: 65437, dtype: object

# %%
data_df.loc[0:10, 'RemoteWork': 'YearsCode']
# Out:
#    RemoteWork   Check                                   CodingActivities  \
# 0      Remote  Apples                                              Hobby
# 1      Remote  Apples  Hobby;Contribute to open-source projects;Other...
# 2      Remote  Apples  Hobby;Contribute to open-source projects;Other...
# 3         NaN  Apples                                                NaN
# 4         NaN  Apples                                                NaN
# 5         NaN  Apples                                                NaN
# 6      Remote  Apples                       I don’t code outside of work
# 7         NaN  Apples                                                NaN
# 8   In-person  Apples                                              Hobby
# 9      Remote  Apples                           Bootstrapping a business
# 10     Remote  Apples           Hobby;Contribute to open-source projects
#
#                                               EdLevel  \
# ...
