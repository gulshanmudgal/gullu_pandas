# %%
import pandas as pd
pd.set_option('display.max_columns', 200)

# %%
person = {
    "first": "Gullu",
    "last": "Ji",
    "email": "gullu@test.com"
}

people = {
    "first": ["gullu", "shiv", "laxman"],
    "last": ["Ji", "Doe", "Doe"],
    "email": ["gullu@test.com", "shiv@test.com", "laxman@test.com"]
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#     first last            email
# 0   gullu   Ji   gullu@test.com
# 1    shiv  Doe    shiv@test.com
# 2  laxman  Doe  laxman@test.com

# %%
lastNameFilter = (df['last'] == "Doe")

# %%
df[lastNameFilter]
# Out:
#     first last            email
# 1    shiv  Doe    shiv@test.com
# 2  laxman  Doe  laxman@test.com

# %%
df[df['last'] == "Doe"] # another approach but not recommended as it's not readable
# Out:
#     first last            email
# 1    shiv  Doe    shiv@test.com
# 2  laxman  Doe  laxman@test.com

# %%
df.loc[lastNameFilter]
# Out:
#     first last            email
# 1    shiv  Doe    shiv@test.com
# 2  laxman  Doe  laxman@test.com

# %%
# the biggest benefit of using loc is that we can even manipulate the column list which is applicable for our case
df.loc[lastNameFilter, ['first', 'email']]
# Out:
#     first            email
# 1    shiv    shiv@test.com
# 2  laxman  laxman@test.com

# %%
complexFilter = (df["last"] == "Doe") & (df['first'] == "shiv")

# %%
df.loc[complexFilter]
# Out:
#   first last          email
# 1  shiv  Doe  shiv@test.com

# %%
complexFilter2 = (df["last"] == "Doe") | (df['first'] == "gullu")

# %%
df.loc[complexFilter2]
# Out:
#     first last            email
# 0   gullu   Ji   gullu@test.com
# 1    shiv  Doe    shiv@test.com
# 2  laxman  Doe  laxman@test.com

# %%
data_df = pd.read_csv('../data/survey_results_public.csv')

# %%
data_df.columns.to_list()
# Out:
# ['ResponseId',
#  'MainBranch',
#  'Age',
#  'EdLevel',
#  'Employment',
#  'EmploymentAddl',
#  'WorkExp',
#  'LearnCodeChoose',
#  'LearnCode',
#  'LearnCodeAI',
#  'AILearnHow',
#  'YearsCode',
#  'DevType',
#  'OrgSize',
#  'ICorPM',
#  'RemoteWork',
#  'PurchaseInfluence',
#  'TechEndorseIntro',
#  'TechEndorse_1',
#  'TechEndorse_2',
#  'TechEndorse_3',
#  'TechEndorse_4',
#  'TechEndorse_5',
#  'TechEndorse_6',
#  'TechEndorse_7',
#  'TechEndorse_8',
#  'TechEndorse_9',
#  'TechEndorse_13',
#  'TechEndorse_13_TEXT',
#  'TechOppose_1',
#  'TechOppose_2',
#  'TechOppose_3',
#  'TechOppose_5',
#  'TechOppose_7',
#  'TechOppose_9',
#  'TechOppose_11',
#  'TechOppose_13',
#  'TechOppose_16',
#  'TechOppose_15',
#  'TechOppose_15_TEXT',
#  'Industry',
#  'JobSatPoints_1',
#  'JobSatPoints_4',
#  'JobSatPoints_5',
#  'JobSatPoints_6',
#  'JobSatPoints_7',
#  'JobSatPoints_8',
#  'JobSatPoints_9',
#  'JobSatPoints_10',
#  'JobSatPoints_11',
#  'JobSatPoints_13',
#  'JobSatPoints_14',
# ...

# %%
data_df
# Out:
#        ResponseId                      MainBranch              Age  \
# 0               1  I am a developer by profession  25-34 years old
# 1               2  I am a developer by profession  25-34 years old
# 2               3  I am a developer by profession  35-44 years old
# 3               4  I am a developer by profession  35-44 years old
# 4               5  I am a developer by profession  35-44 years old
# ...           ...                             ...              ...
# 49118       49119  I am a developer by profession  25-34 years old
# 49119       49120  I am a developer by profession  35-44 years old
# 49120       49121  I am a developer by profession  25-34 years old
# 49121       49122  I am a developer by profession  25-34 years old
# 49122       49123  I am a developer by profession  25-34 years old
#
#                                                  EdLevel  \
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
data_df['ConvertedCompYearly']
# Out:
# 0         61256.0
# 1        104413.0
# 2         53061.0
# 3         36197.0
# 4         60000.0
#            ...
# 49118         NaN
# 49119         NaN
# 49120         NaN
# 49121         NaN
# 49122         NaN
# Name: ConvertedCompYearly, Length: 49123, dtype: float64

# %%
high_salary = data_df["ConvertedCompYearly"] > 90000

# %%
data_df.loc[high_salary, ['Country', 'ConvertedCompYearly']]
# Out:
#                                                  Country  ConvertedCompYearly
# 1                                            Netherlands             104413.0
# 5                                                Ukraine             120000.0
# 25     United Kingdom of Great Britain and Northern I...             108913.0
# 26                                               Ireland             162421.0
# 27                                                Sweden             209643.0
# ...                                                  ...                  ...
# 48970                           United States of America             350000.0
# 48990                           United States of America             167954.0
# 48991                                        Netherlands             110214.0
# 49006                           United States of America             170000.0
# 49007                                     Czech Republic             112334.0
#
# [9647 rows x 2 columns]

# %%
countries = ['United States of America', 'India']
countryFilter = data_df['Country'].isin(countries)

# %%
data_df.loc[countryFilter]
# Out:
#        ResponseId                                         MainBranch  \
# 13             14                     I am a developer by profession
# 15             16                     I am a developer by profession
# 21             22  I am not primarily a developer, but I write co...
# 22             23                     I am a developer by profession
# 29             30                     I am a developer by profession
# ...           ...                                                ...
# 49080       49081                     I am a developer by profession
# 49083       49084  I am not primarily a developer, but I write co...
# 49084       49085  I am not primarily a developer, but I write co...
# 49088       49089  I work with developers or my work supports dev...
# 49089       49090                              I am learning to code
#
#                    Age                                            EdLevel  \
# ...

# %%
languageFilter = data_df["LanguageHaveWorkedWith"].str.contains("Python", na=False)

# %%
data_df.loc[languageFilter, 'LanguageHaveWorkedWith']
# Out:
# 4        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
# 7        Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 8                                        Java;Python;Scala
# 15       Ada;Assembly;C;C#;C++;COBOL;Dart;Delphi;Elixir...
# 17                          HTML/CSS;JavaScript;Python;SQL
#                                ...
# 49061    C;Go;HTML/CSS;JavaScript;MATLAB;MicroPython;Py...
# 49088                                           Python;SQL
# 49089    C;C#;C++;HTML/CSS;Java;JavaScript;PHP;PowerShe...
# 49105    C++;Dart;GDScript;HTML/CSS;JavaScript;PHP;Powe...
# 49106    Bash/Shell (all shells);Delphi;PowerShell;Pyth...
# Name: LanguageHaveWorkedWith, Length: 18444, dtype: object
